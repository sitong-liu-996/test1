# %% [markdown]
# print("Hello World")

# %%
## print out 
print("Hello")
# Out:
# Hello

# %% [markdown]
# a=1+1
# print(a)

# %%
# exercise 2 write and execute code
a=1+1
print(a)
# Out:
# 2

# %%
## print out 
print("Hello")
print("word")
# Out:
# Hello
# word
